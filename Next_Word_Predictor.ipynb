# %%
faq = """What is Python
How do I install Python
What is a variable in Python
How do I create a list in Python
What is a function in Python
How do I define a function
What is an if statement
How do I install libraries in Python
What is a loop
What are classes in Python
How do I handle errors in Python
What are Python dictionaries
How do I read a file in Python
What is the difference between list and tuple
How can I make comments in Python
What is a module
How do I import a module
What is a lambda function
How do I exit a program in Python
What is the difference between Python 2 and Python 3
What makes Python a popular programming language
How can I get started with installing Python
What are variables, and how are they used in Python
How do you create and use lists in Python
What are functions in Python, and why are they useful
What are the steps to define a function in Python
How do conditional statements like if-else work in Python
What’s the best way to install libraries in Python
How do loops like 'for' and 'while' function in Python
What are classes, and how do they relate to Python's OOP
How can I manage errors and exceptions in Python
What are dictionaries, and how do they store data in Python
How can I open and read files in Python
In what ways are lists different from tuples in Python
What’s the syntax for making comments in Python code
What’s a module, and how do I use one in Python
What’s the proper way to import modules in Python
How do lambda functions work, and when should I use them
What’s the easiest way to stop or exit a Python program
How does Python 3 differ from Python 2, and which should I learn
What is Python and what can it be used for
What are the different versions of Python and how do they differ
How can I install Python on Windows, Mac, and Linux
How can I check the current version of Python installed on my computer
What is an IDE and which ones are best for Python development
How do I write and execute my first Python program
What are Python variables, and how do they differ from constants
How do I create and manipulate lists, sets, and dictionaries in Python
What is type casting, and how do I use it in Python
How do functions in Python improve code reusability and readability
What is the purpose of Python’s return statement in functions
How do global and local variables work in Python functions
How do I use conditions and control flow with if-else statements in Python
How can I use logical operators to enhance conditional statements in Python
What are Python loops, and when should I use for vs while loops
What are nested loops, and how can they be used effectively in Python
How do I use list comprehension to make code more concise in Python
How can I handle and prevent errors in Python code using try-except blocks
What is a stack trace, and how can it help debug errors in Python
How do I create, open, and read text files in Python
How can I write data to a file and ensure data is saved correctly in Python
What is a class in Python, and how does it relate to object-oriented programming
What is the difference between instance and class variables in Python
How can I create multiple instances of a class in Python
What are the key differences between functions and methods in Python
How does inheritance work in Python, and why is it useful
How do I use super() to access parent class methods in Python
What is polymorphism, and how can I implement it in Python
What are decorators in Python, and when should I use them
How can I make and call an anonymous (lambda) function in Python
How does Python handle memory management and garbage collection
What are Python modules and packages, and how do they improve organization
How do I create and import my own modules in Python
How can I find and install third-party packages with pip
How do I create a virtual environment, and why is it beneficial in Python
What are Python generators, and how do they differ from regular functions
How can I use Python’s map, filter, and reduce functions for data processing
What is multithreading, and how can it improve performance in Python
How does asynchronous programming work in Python, and when should I use it
What is JSON, and how can I read and write JSON data in Python
How can I work with APIs and fetch data from the web in Python
How can I use regular expressions for pattern matching in Python
What is a docstring, and how can it improve code documentation in Python
How can I test Python code for bugs and ensure accuracy
What are f-strings, and how do they simplify string formatting in Python
How do I profile and optimize the performance of Python code
How can I develop and deploy a web application using Python frameworks
How does machine learning work in Python, and which libraries are popular"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faq])

# %%
tokenizer.word_index
# Out:
# {'python': 1,
#  'how': 2,
#  'and': 3,
#  'in': 4,
#  'i': 5,
#  'what': 6,
#  'do': 7,
#  'can': 8,
#  'is': 9,
#  'a': 10,
#  'are': 11,
#  'the': 12,
#  'use': 13,
#  'they': 14,
#  'to': 15,
#  'it': 16,
#  'functions': 17,
#  'create': 18,
#  'work': 19,
#  'for': 20,
#  'code': 21,
#  'function': 22,
#  'data': 23,
#  'does': 24,
#  'install': 25,
#  'what’s': 26,
#  'from': 27,
#  'should': 28,
#  'of': 29,
#  'errors': 30,
#  'read': 31,
#  'between': 32,
#  'with': 33,
#  'variables': 34,
#  'loops': 35,
#  'when': 36,
#  'differ': 37,
#  'improve': 38,
#  'class': 39,
#  'list': 40,
#  'an': 41,
#  'if': 42,
#  'libraries': 43,
#  'handle': 44,
#  'dictionaries': 45,
#  'difference': 46,
#  'make': 47,
#  'module': 48,
#  'import': 49,
#  'lambda': 50,
#  'program': 51,
#  'programming': 52,
#  'used': 53,
#  'lists': 54,
#  'why': 55,
#  'statements': 56,
#  'way': 57,
#  'modules': 58,
#  'which': 59,
#  'my': 60,
#  'write': 61,
#  'define': 62,
#  'statement': 63,
# ...

# %%
len(tokenizer.word_index)
# Out:
# 226

# %%
input_sequences = []
for i in faq.split("\n"):
  tokenized_sentences = tokenizer.texts_to_sequences([i])[0]

  for i in range(1, len(tokenized_sentences)):
    input_sequences.append(tokenized_sentences[:i+1])

# %%
input_sequences
# Out:
# [[6, 9],
#  [6, 9, 1],
#  [2, 7],
#  [2, 7, 5],
#  [2, 7, 5, 25],
#  [2, 7, 5, 25, 1],
#  [6, 9],
#  [6, 9, 10],
#  [6, 9, 10, 92],
#  [6, 9, 10, 92, 4],
#  [6, 9, 10, 92, 4, 1],
#  [2, 7],
#  [2, 7, 5],
#  [2, 7, 5, 18],
#  [2, 7, 5, 18, 10],
#  [2, 7, 5, 18, 10, 40],
#  [2, 7, 5, 18, 10, 40, 4],
#  [2, 7, 5, 18, 10, 40, 4, 1],
#  [6, 9],
#  [6, 9, 10],
#  [6, 9, 10, 22],
#  [6, 9, 10, 22, 4],
#  [6, 9, 10, 22, 4, 1],
#  [2, 7],
#  [2, 7, 5],
#  [2, 7, 5, 62],
#  [2, 7, 5, 62, 10],
#  [2, 7, 5, 62, 10, 22],
#  [6, 9],
#  [6, 9, 41],
#  [6, 9, 41, 42],
#  [6, 9, 41, 42, 63],
#  [2, 7],
#  [2, 7, 5],
#  [2, 7, 5, 25],
#  [2, 7, 5, 25, 43],
#  [2, 7, 5, 25, 43, 4],
#  [2, 7, 5, 25, 43, 4, 1],
#  [6, 9],
#  [6, 9, 10],
#  [6, 9, 10, 93],
#  [6, 11],
#  [6, 11, 64],
#  [6, 11, 64, 4],
#  [6, 11, 64, 4, 1],
#  [2, 7],
#  [2, 7, 5],
#  [2, 7, 5, 44],
#  [2, 7, 5, 44, 30],
#  [2, 7, 5, 44, 30, 4],
#  [2, 7, 5, 44, 30, 4, 1],
#  [6, 11],
#  [6, 11, 1],
#  [6, 11, 1, 45],
#  [2, 7],
# ...

# %%
max_len = max([len(x) for x in input_sequences])

# %%
max_len
# Out:
# 16

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding = "pre")

# %%
padded_input_sequences
# Out:
# array([[ 0,  0,  0, ...,  0,  6,  9],
#        [ 0,  0,  0, ...,  6,  9,  1],
#        [ 0,  0,  0, ...,  0,  2,  7],
#        ...,
#        [ 0,  0,  0, ...,  3, 59, 43],
#        [ 0,  0,  0, ..., 59, 43, 11],
#        [ 0,  0,  0, ..., 43, 11, 70]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape, y.shape
# Out:
# ((805, 15), (805,))

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y, num_classes = 227)

# %%
y.shape
# Out:
# (805, 227)

# %% [markdown]
# ###**Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

model = Sequential()
model.add(Embedding(227, 100, input_length= max_len-1))
model.add(LSTM(150))
model.add(Dense(227, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X, y, epochs = 100)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.0853 - loss: 5.2440
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - accuracy: 0.0816 - loss: 4.5033
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.1236 - loss: 4.4488
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.1982 - loss: 4.2471
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.2484 - loss: 3.9164
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.2675 - loss: 3.8946
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.2895 - loss: 3.6542
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2908 - loss: 3.3988
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3228 - loss: 3.3161
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3352 - loss: 3.1979
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3923 - loss: 3.0189
# ...

# %%
import numpy as np

text = "How"

for i in range(20):
  # Tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]

  # Padding
  padded_token_text = pad_sequences([token_text], maxlen = max_len-1, padding = "pre")

  # Predict
  pos = np.argmax(model.predict(padded_token_text))

  for word, index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# How do
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# How do i
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# How do i create
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# How do i create a
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# How do i create a list
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# How do i create a list in
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# How do i create a list in python
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# How do i create a list in python and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# How do i create a list in python and why
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# How do i create a list in python and why is
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# How do i create a list in python and why is it
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# How do i create a list in python and why is it beneficial
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# How do i create a list in python and why is it beneficial in
# ...
